# %% [markdown]
# Kütüphaneleri içe aktarıyoruz

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

# Uyarıların gizlenmesi
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Data seti

# %%
fish_dir = '/kaggle/input/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset'

# %% [markdown]
# Data setinin içeriğini listeliyoruz

# %%
fish_dir = '/kaggle/input/a-large-scale-fish-dataset/Fish_Dataset/Fish_Dataset' 
classes = [i for i in os.listdir(fish_dir) if '.' not in i]                    
classes
# Out:
# ['Hourse Mackerel',
#  'Black Sea Sprat',
#  'Sea Bass',
#  'Red Mullet',
#  'Trout',
#  'Striped Red Mullet',
#  'Shrimp',
#  'Gilt-Head Bream',
#  'Red Sea Bream']

# %% [markdown]
# PNG dosyalarını ve bunların bulunduğu dizin adlarını toplamak için bu kodu yazarız

# %%
label = []
path = []


for dir_name, _,filenames in os.walk(fish_dir):                    
    for filename in filenames:                                 
        if os.path.splitext(filename)[-1]=='.png':               
            if dir_name.split()[-1]!='GT':                       
                label.append(os.path.split(dir_name)[-1])         
                path.append(os.path.join(dir_name,filename))     

data=pd.DataFrame(columns=['path','label'])
data['path']=path
data['label']=label

# %% [markdown]
# Veri yapısını görüntüleme

# %%
df = pd.DataFrame({'path': path, 'label': label})
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   path    9000 non-null   object
#  1   label   9000 non-null   object
# dtypes: object(2)
# memory usage: 140.8+ KB
# None

# %% [markdown]
# df etiketleri çubuk grafikle görselleştirme

# %%
df['label'].value_counts().plot.bar()
print(df['label'].value_counts())
# Out:
# label
# Hourse Mackerel       1000
# Black Sea Sprat       1000
# Sea Bass              1000
# Red Mullet            1000
# Trout                 1000
# Striped Red Mullet    1000
# Shrimp                1000
# Gilt-Head Bream       1000
# Red Sea Bream         1000
# Name: count, dtype: int64

# %% [markdown]
# Son beş satırı görüntüle

# %%
data.tail()
# Out:
#                                                    path          label
# 8995  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Red Sea Bream
# 8996  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Red Sea Bream
# 8997  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Red Sea Bream
# 8998  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Red Sea Bream
# 8999  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Red Sea Bream

# %% [markdown]
# Sırayla ilk beş satırı yazdırır,bilgi verir,her bir etiketin kaç kez geçtiğini sayar

# %%
print(data.head())
print(data.info())
print(data['label'].value_counts())
# Out:
#                                                 path            label
# 0  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Hourse Mackerel
# 1  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Hourse Mackerel
# 2  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Hourse Mackerel
# 3  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Hourse Mackerel
# 4  /kaggle/input/a-large-scale-fish-dataset/Fish_...  Hourse Mackerel
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   path    9000 non-null   object
#  1   label   9000 non-null   object
# dtypes: object(2)
# memory usage: 140.8+ KB
# None
# label
# Hourse Mackerel       1000
# Black Sea Sprat       1000
# Sea Bass              1000
# Red Mullet            1000
# Trout                 1000
# Striped Red Mullet    1000
# Shrimp                1000
# Gilt-Head Bream       1000
# Red Sea Bream         1000
# Name: count, dtype: int64

# %% [markdown]
# Verileri görselleştiriyoruz

# %%
cn = 0
plt.figure(figsize=(20,10))
for unique_label in data['label'].unique():
    plt.subplot(3, 3, cn+1)
    plt.imshow(plt.imread(data[data['label']==unique_label].iloc[0,0]))
    plt.title(unique_label)
    plt.axis('off')
    cn+=1

# %% [markdown]
# Bu kod, görüntü verilerini ön işlemek ve eğitim/validation setleri oluşturmak için ImageDataGenerator sınıfını kullanır.
# ImageDataGenerator: datagen değişkeni, görüntülerin ölçeklendirilmesi için rescale=1./255 ile tanımlanır. Bu, görüntü değerlerini 0 ile 1 arasında normalize eder.
# Her görüntü 64x64 olarak ayarlanıyor.

# %%
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)


train_generator = datagen.flow_from_directory(
    fish_dir,
    target_size=(64, 64),  # Görüntü boyutu 64x64 piksel olarak ayarlanıyor
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    fish_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 14400 images belonging to 9 classes.
# Found 3600 images belonging to 9 classes.

# %% [markdown]
# Sequential ile model tanımlayarak başlarız,giriş katmanındaki verileri flatten ile düzleştirir.Gizli katmanlar için relu aktivasyon fonksiyonunu kullanır.Çıkış katmanı için 'softmax' aktivasyon fonksiyonu ile çıkış verir.Optimize edip verilerin yapısı ve katmanı hakkında modal.summary() bilgi verir.

# %%
model = Sequential()

# Giriş katmanı 
model.add(Flatten(input_shape=(64, 64, 3)))

# Gizli katmanlar
model.add(Dense(128, activation='relu'))  
model.add(Dense(64, activation='relu'))   

# Çıkış katmanı
model.add(Dense(train_generator.num_classes, activation='softmax'))


model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 12288)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,572,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 9)              │           585 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,581,833 (6.03 MB)
#  Trainable params: 1,581,833 (6.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Model.fit() fonksiyonu, modelin eğitim verileri (train_generator) ile eğitilmesini sağlar.
# validation_data=validation_generator parametresi ile her epoch sonunda modelin performansını değerlendirmek için doğrulama verileri kullanılır.
# Epoch Sayısı: epochs=20 ile modelin toplamda 20 defa eğitim verileri üzerinde eğitim alması belirtilir. Her epoch, modelin tüm eğitim verisi üzerinden bir geçiş yapmasını ifade eder.
#
# Sonuçları history değişkeninde saklar, bu sayede eğitim ve doğrulama kayıplarını ve doğruluk değerlerini daha sonra analiz edebilirsiniz.

# %%
history = model.fit(train_generator, validation_data=validation_generator, epochs=20)
# Out:
# Epoch 1/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 217s 475ms/step - accuracy: 0.3189 - loss: 1.8690 - val_accuracy: 0.3381 - val_loss: 1.8102
# Epoch 2/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 120s 263ms/step - accuracy: 0.5692 - loss: 1.1462 - val_accuracy: 0.4561 - val_loss: 1.4751
# Epoch 3/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 119s 262ms/step - accuracy: 0.6666 - loss: 0.9127 - val_accuracy: 0.5578 - val_loss: 1.2057
# Epoch 4/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 118s 261ms/step - accuracy: 0.7153 - loss: 0.7670 - val_accuracy: 0.6272 - val_loss: 1.0326
# Epoch 5/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 118s 259ms/step - accuracy: 0.7604 - loss: 0.6601 - val_accuracy: 0.5236 - val_loss: 1.3563
# Epoch 6/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 119s 261ms/step - accuracy: 0.7933 - loss: 0.5731 - val_accuracy: 0.5844 - val_loss: 1.2054
# Epoch 7/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 118s 261ms/step - accuracy: 0.8264 - loss: 0.4817 - val_accuracy: 0.6922 - val_loss: 0.8835
# Epoch 8/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 119s 262ms/step - accuracy: 0.8350 - loss: 0.4467 - val_accuracy: 0.5758 - val_loss: 1.5816
# Epoch 9/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 118s 260ms/step - accuracy: 0.8569 - loss: 0.3911 - val_accuracy: 0.6825 - val_loss: 0.9135
# Epoch 10/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 120s 265ms/step - accuracy: 0.8708 - loss: 0.3546 - val_accuracy: 0.6728 - val_loss: 1.0729
# Epoch 11/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 120s 264ms/step - accuracy: 0.8943 - loss: 0.2977 - val_accuracy: 0.6119 - val_loss: 1.3644
# Epoch 12/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 119s 261ms/step - accuracy: 0.9015 - loss: 0.2865 - val_accuracy: 0.6981 - val_loss: 1.0018
# Epoch 13/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 118s 260ms/step - accuracy: 0.9093 - loss: 0.2597 - val_accuracy: 0.6739 - val_loss: 1.1121
# Epoch 14/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 118s 260ms/step - accuracy: 0.9180 - loss: 0.2338 - val_accuracy: 0.7047 - val_loss: 0.9274
# Epoch 15/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 118s 260ms/step - accuracy: 0.9268 - loss: 0.2086 - val_accuracy: 0.7450 - val_loss: 0.8174
# Epoch 16/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 119s 263ms/step - accuracy: 0.9276 - loss: 0.2028 - val_accuracy: 0.7169 - val_loss: 0.9506
# Epoch 17/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 120s 263ms/step - accuracy: 0.9405 - loss: 0.1704 - val_accuracy: 0.6664 - val_loss: 1.3282
# Epoch 18/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 121s 267ms/step - accuracy: 0.9369 - loss: 0.1692 - val_accuracy: 0.7172 - val_loss: 1.0139
# Epoch 19/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 120s 263ms/step - accuracy: 0.9505 - loss: 0.1423 - val_accuracy: 0.7600 - val_loss: 0.8475
# Epoch 20/20
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 119s 261ms/step - accuracy: 0.9483 - loss: 0.1434 - val_accuracy: 0.7539 - val_loss: 0.9417

# %% [markdown]
# Veri setinin performansını değerlendirir.Model.evaluate(validation_generator) fonksiyonu, modelin doğrulama verileri üzerindeki loss ve accuracy değerlerini hesaplar. Bu, modelin eğitim sırasında öğrendiklerini ne kadar iyi genelleyebildiğini ölçer.
# test_loss ve test_acc değişkenleri, modelin kayıp ve doğruluk değerlerini saklar.

# %%
test_loss, test_acc = model.evaluate(validation_generator)
print(f"Test doğruluğu: {test_acc:.4f}")
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 40s 353ms/step - accuracy: 0.7604 - loss: 0.9203
# Test doğruluğu: 0.7539

# %% [markdown]
# Accuracy ve loss değerlerini görselleştirir.

# %%
plt.figure(figsize=(12, 5))

# Loss 
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Grafiği')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy 
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Grafiği')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# İlk 4 tahmini ve gerçek etiketleri karşılaştırma

# %%
predictions = model.predict(validation_generator)


for i in range(4):
    img, label = validation_generator[i]
    plt.imshow(img[0])
    plt.title(f"Tahmin: {np.argmax(predictions[i])}, Gerçek: {np.argmax(label[0])}")
    plt.show()
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 40s 352ms/step

# %% [markdown]
# Karışıklık matrisi ve sınıflandırma raporu, bir sınıflandırma modelinin performansını değerlendirmek için kullanılır.
# Karışıklık matrisi, modelin tahmin ettiği sınıfları ve gerçek sınıfları karşılaştırarak, her sınıf için doğru ve yanlış tahminleri gösteren bir tablodur.
# Sınıflandırma raporu, her sınıf için çeşitli performansı  özetler.
# Tahminleri ve gerçek etiketleri aldıktan sonra karışıklık matrisi oluşturup,görselleştiririz ve   raporu oluştururuz.

# %%
predictions = model.predict(validation_generator)
predicted_classes = np.argmax(predictions, axis=1)


true_classes = validation_generator.classes


conf_matrix = confusion_matrix(true_classes, predicted_classes)


plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=validation_generator.class_indices.keys(), yticklabels=validation_generator.class_indices.keys())
plt.title('Karışıklık Matrisi')
plt.xlabel('Tahmin Edilen')
plt.ylabel('Gerçek')
plt.show()


report = classification_report(true_classes, predicted_classes, target_names=validation_generator.class_indices.keys())
print(report)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 40s 354ms/step
#                     precision    recall  f1-score   support
#
#    Black Sea Sprat       0.09      0.12      0.10       400
#    Gilt-Head Bream       0.12      0.11      0.11       400
#    Hourse Mackerel       0.10      0.15      0.12       400
#         Red Mullet       0.15      0.17      0.16       400
#      Red Sea Bream       0.11      0.08      0.10       400
#           Sea Bass       0.11      0.08      0.10       400
#             Shrimp       0.12      0.11      0.12       400
# Striped Red Mullet       0.10      0.11      0.11       400
#              Trout       0.14      0.08      0.10       400
#
#           accuracy                           0.11      3600
#          macro avg       0.12      0.11      0.11      3600
#       weighted avg       0.12      0.11      0.11      3600
